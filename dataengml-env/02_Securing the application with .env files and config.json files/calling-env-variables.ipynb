# %% [markdown]
# .env files are used to store environment specific variables such as API keys, database credentials and other sensitive information.
# config.json files are used to store application configuration settings.
# <br>
# <br>Scope : .env is for environment-specific settings, while config is for general application settings.
# <br>Security: .env files are not versioned to protect sensitive data whereas config files can be versioned.
# <br>Access: .env files are accessed at runtime, while config values are often cached for performance.
# <br>
# <br><b>Note: Naming of .env file is '.env'.</b>

# %% [markdown]
# <b>Service Principal Authentication</b>

# %%
# %pip install python-dotenv
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from azureml.core.authentication import ServicePrincipalAuthentication
import json
from azureml.core import Workspace

# Load environment variables from .env file
load_dotenv()

# Open and read the JSON file
with open('config.json', 'r') as file:
    config = json.load(file)

svc_pr = ServicePrincipalAuthentication(tenant_id=os.getenv("TENANT_ID"),
                                        service_principal_id=os.getenv("SERVICE_PRINCIPAL_ID"),
                                        service_principal_password=os.getenv("SERVICE_PRINCIPAL_PASSWORD"))

ws = Workspace(subscription_id=config['subscription_id'],
                resource_group=config['resource_group'],
                workspace_name=config['workspace_name'],
                auth=svc_pr)

print("Found workspace {} at location {}".format(ws.name, ws.location))
# Out:
# Found workspace data-engineering-ml-001 at location westeurope
